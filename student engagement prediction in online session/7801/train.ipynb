# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('7801.csv')

# %%
df.columns = [each.strip() for each in df.columns]
df.columns
# Out:
# Index(['Total_Items', 'Time_Spent_ in Course', 'Total_Logins',
#        'Activity_inside_content_ area', 'User_Activity_in_Goup',
#        'Nbre_of_clics', 'Nbre_of_ message_ participation', 'join_session',
#        'Time_Spent_on_Session_Attendence', 'Level'],
#       dtype='object')

# %%
df
# Out:
#     Total_Items  Time_Spent_ in Course  Total_Logins
# 0      0.506494               1.000000      0.316754  \
# 1      0.194805               0.005378      0.164921
# 2      0.402597               0.109859      0.253927
# 3      0.480519               0.438156      0.285340
# 4      0.168831               0.001024      0.083770
# ..          ...                    ...           ...
# 95     0.831169               0.385915      0.204188
# 96     0.831169               0.385915      0.204188
# 97     0.116883               0.032522      0.057592
# 98     0.792208               0.258899      1.000000
# 99     0.051948               0.187196      0.000000
#
#     Activity_inside_content_ area  User_Activity_in_Goup  Nbre_of_clics
# 0                        0.370166               0.097561       0.592593  \
# 1                        0.104972               0.024390       0.296296
# 2                        0.241252               0.008130       0.296296
# 3                        0.237569               0.097561       0.407407
# 4                        0.081031               0.406504       0.000000
# ..                            ...                    ...            ...
# 95                       0.267035               0.162602       0.481481
# 96                       0.267035               0.162602       0.481481
# 97                       0.046041               0.032520       0.259259
# 98                       1.000000               0.975610       0.777778
# 99                       0.007366               0.048780       0.000000
#
#     Nbre_of_ message_ participation  join_session
# 0                          0.444444      0.555556  \
# 1                          0.111111      0.000000
# 2                          0.333333      0.777778
# 3                          0.333333      0.888889
# 4                          0.000000      0.333333
# ..                              ...           ...
# 95                         0.777778      1.000000
# 96                         0.777778      1.000000
# 97                         0.000000      0.444444
# 98                         0.888889      1.000000
# 99                         0.000000      0.111111
#
#     Time_Spent_on_Session_Attendence Level
# 0                           0.466667    PE
# 1                           0.066667    NE
# 2                           0.600000    PE
# 3                           0.666667    PE
# 4                           0.400000    NE
# ..                               ...   ...
# 95                          0.466667    PE
# 96                          0.466667    PE
# 97                          0.200000    NE
# 98                          0.000000    AE
# 99                          0.000000    NE
#
# [100 rows x 10 columns]

# %%
df.dtypes
# Out:
# Total_Items                         float64
# Time_Spent_ in Course               float64
# Total_Logins                        float64
# Activity_inside_content_ area       float64
# User_Activity_in_Goup               float64
# Nbre_of_clics                       float64
# Nbre_of_ message_ participation     float64
# join_session                        float64
# Time_Spent_on_Session_Attendence    float64
# Level                                object
# dtype: object

# %%
plt.hist(df['Total_Items'], bins=20)
plt.title('Distribution of Total_Items')
plt.xlabel('Total_Items')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Time_Spent_ in Course'], bins=20)
plt.title('Distribution of Time_Spent_ in Course')
plt.xlabel('Time_Spent_ in Course')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Total_Logins'], bins=20)
plt.title('Distribution of Total_Logins')
plt.xlabel('Total_Logins')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Nbre_of_clics'], bins=20)
plt.title('Distribution of Nbre_of_clics')
plt.xlabel('Nbre_of_clics')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Nbre_of_ message_ participation'], bins=20)
plt.title('Distribution of Nbre_of_ message_ participation')
plt.xlabel('Nbre_of_ message_ participation')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Time_Spent_ in Course'], bins=10)
plt.title('Distribution of Time Spent in Course')
plt.xlabel('Time Spent in Course')
plt.ylabel('Frequency')
plt.show()

# %%
plt.scatter(df['Time_Spent_ in Course'], df['Total_Items'])
plt.title('Scatter plot of Time Spent in Course vs Total Items')
plt.xlabel('Time Spent in Course')
plt.ylabel('Total Items')
plt.show()

# %%
import seaborn as sns

sns.barplot(x='Level', y='Total_Logins', data=df)
plt.title('Mean Total Logins for each Level')
plt.show()

# %%
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
#       2 plt.title('Correlation Matrix Heatmap')
#       3 plt.show()
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10059, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10057 cols = data.columns
#   10058 idx = cols.copy()
# > 10059 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10061 if method == "pearson":
#   10062     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: 'PE'

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df['Level'] =le.fit_transform(df['Level'])
df
# Out:
#     Total_Items  Time_Spent_ in Course  Total_Logins
# 0      0.506494               1.000000      0.316754  \
# 1      0.194805               0.005378      0.164921
# 2      0.402597               0.109859      0.253927
# 3      0.480519               0.438156      0.285340
# 4      0.168831               0.001024      0.083770
# ..          ...                    ...           ...
# 95     0.831169               0.385915      0.204188
# 96     0.831169               0.385915      0.204188
# 97     0.116883               0.032522      0.057592
# 98     0.792208               0.258899      1.000000
# 99     0.051948               0.187196      0.000000
#
#     Activity_inside_content_ area  User_Activity_in_Goup  Nbre_of_clics
# 0                        0.370166               0.097561       0.592593  \
# 1                        0.104972               0.024390       0.296296
# 2                        0.241252               0.008130       0.296296
# 3                        0.237569               0.097561       0.407407
# 4                        0.081031               0.406504       0.000000
# ..                            ...                    ...            ...
# 95                       0.267035               0.162602       0.481481
# 96                       0.267035               0.162602       0.481481
# 97                       0.046041               0.032520       0.259259
# 98                       1.000000               0.975610       0.777778
# 99                       0.007366               0.048780       0.000000
#
#     Nbre_of_ message_ participation  join_session
# 0                          0.444444      0.555556  \
# 1                          0.111111      0.000000
# 2                          0.333333      0.777778
# 3                          0.333333      0.888889
# 4                          0.000000      0.333333
# ..                              ...           ...
# 95                         0.777778      1.000000
# 96                         0.777778      1.000000
# 97                         0.000000      0.444444
# 98                         0.888889      1.000000
# 99                         0.000000      0.111111
#
#     Time_Spent_on_Session_Attendence  Level
# 0                           0.466667      2
# 1                           0.066667      1
# 2                           0.600000      2
# 3                           0.666667      2
# 4                           0.400000      1
# ..                               ...    ...
# 95                          0.466667      2
# 96                          0.466667      2
# 97                          0.200000      1
# 98                          0.000000      0
# 99                          0.000000      1
#
# [100 rows x 10 columns]

# %%
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
X = df.drop('Level', axis=1)
y = df['Level']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# initialize and train the models
lr = LogisticRegression()
lr.fit(X_train, y_train)

dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)

rf = RandomForestClassifier()
rf.fit(X_train, y_train)

svm = SVC()
svm.fit(X_train, y_train)

# make predictions on test data
y_pred_lr = lr.predict(X_test)
y_pred_dt = dt.predict(X_test)
y_pred_rf = rf.predict(X_test)
y_pred_svm = svm.predict(X_test)

# evaluate model performance
acc_lr = accuracy_score(y_test, y_pred_lr)
acc_dt = accuracy_score(y_test, y_pred_dt)
acc_rf = accuracy_score(y_test, y_pred_rf)
acc_svm = accuracy_score(y_test, y_pred_svm)

# %%
print(f"Logistic Regression Accuracy: {acc_lr}")
print(f"Decision Tree Accuracy: {acc_dt}")
print(f"Random Forest Accuracy: {acc_rf}")
print(f"SVM Accuracy: {acc_svm}")
# Out:
# Logistic Regression Accuracy: 0.8666666666666667
# Decision Tree Accuracy: 0.7333333333333333
# Random Forest Accuracy: 0.9666666666666667
# SVM Accuracy: 0.8666666666666667

# %%
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix
import seaborn as sns

from keras.models import Sequential
from keras.layers import Dense, Conv1D, Flatten, MaxPooling1D
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from keras.layers import Input, Dense, LSTM, MaxPooling1D, Conv1D, TimeDistributed
from keras.layers import Dense, Flatten, Dropout
from keras.models import Model
from sklearn import metrics
import tensorflow as tf
from numpy import unique
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
labels = df['Level'] # target feature
df.drop(['Level'], axis = 1, inplace=True)

df # input features
# Out:
#     Total_Items  Time_Spent_ in Course  Total_Logins
# 0      0.506494               1.000000      0.316754  \
# 1      0.194805               0.005378      0.164921
# 2      0.402597               0.109859      0.253927
# 3      0.480519               0.438156      0.285340
# 4      0.168831               0.001024      0.083770
# ..          ...                    ...           ...
# 95     0.831169               0.385915      0.204188
# 96     0.831169               0.385915      0.204188
# 97     0.116883               0.032522      0.057592
# 98     0.792208               0.258899      1.000000
# 99     0.051948               0.187196      0.000000
#
#     Activity_inside_content_ area  User_Activity_in_Goup  Nbre_of_clics
# 0                        0.370166               0.097561       0.592593  \
# 1                        0.104972               0.024390       0.296296
# 2                        0.241252               0.008130       0.296296
# 3                        0.237569               0.097561       0.407407
# 4                        0.081031               0.406504       0.000000
# ..                            ...                    ...            ...
# 95                       0.267035               0.162602       0.481481
# 96                       0.267035               0.162602       0.481481
# 97                       0.046041               0.032520       0.259259
# 98                       1.000000               0.975610       0.777778
# 99                       0.007366               0.048780       0.000000
#
#     Nbre_of_ message_ participation  join_session
# 0                          0.444444      0.555556  \
# 1                          0.111111      0.000000
# 2                          0.333333      0.777778
# 3                          0.333333      0.888889
# 4                          0.000000      0.333333
# ..                              ...           ...
# 95                         0.777778      1.000000
# 96                         0.777778      1.000000
# 97                         0.000000      0.444444
# 98                         0.888889      1.000000
# 99                         0.000000      0.111111
#
#     Time_Spent_on_Session_Attendence
# 0                           0.466667
# 1                           0.066667
# 2                           0.600000
# 3                           0.666667
# 4                           0.400000
# ..                               ...
# 95                          0.466667
# 96                          0.466667
# 97                          0.200000
# 98                          0.000000
# 99                          0.000000
#
# [100 rows x 9 columns]

# %%
y = labels.to_numpy()
x = df.to_numpy()

print(x.shape)
x = x.reshape(x.shape[0], x.shape[1], 1)
print(x.shape)

Xtrain, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

print(Xtrain.shape, y_train.shape, X_test.shape, y_test.shape)

ytrain = tf.keras.utils.to_categorical(y_train)
ytest = tf.keras.utils.to_categorical(y_test)

n_timesteps, n_features, n_outputs = Xtrain.shape[1], Xtrain.shape[2], ytest.shape[1]


# define CNN model
feature_extractor = Sequential()
feature_extractor.add(Conv1D(filters=64, kernel_size=3, activation='tanh', input_shape=(n_timesteps,n_features)))
feature_extractor.add(Conv1D(filters=64, kernel_size=3, activation='tanh'))
feature_extractor.add(MaxPooling1D(pool_size=1))

# define LSTM model
model = Sequential()
model.add(feature_extractor)
model.add(LSTM(100))
model.add(Dense(50, activation='tanh'))
model.add(Dense(n_outputs, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.build((n_timesteps,n_features))

model.summary()
print("Model Architecture Ready")
# Out:
# (100, 9)
# (100, 9, 1)
# (70, 9, 1) (70,) (30, 9, 1) (30,)
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 5, 64)             12608
#
#  lstm (LSTM)                 (None, 100)               66000
#
#  dense (Dense)               (None, 50)                5050
#
#  dense_1 (Dense)             (None, 3)                 153
#
# =================================================================
# Total params: 83,811
# Trainable params: 83,811
# Non-trainable params: 0
# _________________________________________________________________
# Model Architecture Ready

# %%
print("Model Training Started")
verbose, epochs, batch_size = 1, 200, 64 #32

history = model.fit(X_test, ytest, validation_split=0.3, batch_size=batch_size, epochs=epochs, verbose=verbose)
print("Model Training Completed")

acc = model.evaluate(X_test, ytest)
print("Model Evaluation Completed")

print("Loss:", acc[0], " Accuracy:", acc[1])
# Out:
# Model Training Started
# Epoch 1/200
# 1/1 [==============================] - 3s 3s/step - loss: 1.1271 - accuracy: 0.2381 - val_loss: 1.0865 - val_accuracy: 0.3333
# Epoch 2/200
# 1/1 [==============================] - 0s 72ms/step - loss: 1.0629 - accuracy: 0.5238 - val_loss: 1.0639 - val_accuracy: 0.3333
# Epoch 3/200
# 1/1 [==============================] - 0s 66ms/step - loss: 1.0048 - accuracy: 0.5238 - val_loss: 1.0466 - val_accuracy: 0.3333
# Epoch 4/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.9518 - accuracy: 0.5238 - val_loss: 1.0369 - val_accuracy: 0.3333
# Epoch 5/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.9065 - accuracy: 0.5238 - val_loss: 1.0383 - val_accuracy: 0.3333
# Epoch 6/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.8739 - accuracy: 0.5238 - val_loss: 1.0505 - val_accuracy: 0.3333
# Epoch 7/200
# 1/1 [==============================] - 0s 67ms/step - loss: 0.8581 - accuracy: 0.5238 - val_loss: 1.0676 - val_accuracy: 0.3333
# Epoch 8/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.8561 - accuracy: 0.5238 - val_loss: 1.0781 - val_accuracy: 0.3333
# Epoch 9/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.8577 - accuracy: 0.5238 - val_loss: 1.0733 - val_accuracy: 0.3333
# Epoch 10/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.8528 - accuracy: 0.5238 - val_loss: 1.0536 - val_accuracy: 0.3333
# Epoch 11/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.8390 - accuracy: 0.5238 - val_loss: 1.0252 - val_accuracy: 0.3333
# Epoch 12/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.8204 - accuracy: 0.5238 - val_loss: 0.9950 - val_accuracy: 0.3333
# Epoch 13/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.8023 - accuracy: 0.5238 - val_loss: 0.9678 - val_accuracy: 0.3333
# Epoch 14/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.7880 - accuracy: 0.5238 - val_loss: 0.9453 - val_accuracy: 0.4444
# Epoch 15/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.7773 - accuracy: 0.5714 - val_loss: 0.9265 - val_accuracy: 0.4444
# Epoch 16/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.7674 - accuracy: 0.5714 - val_loss: 0.9093 - val_accuracy: 0.4444
# Epoch 17/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.7553 - accuracy: 0.5714 - val_loss: 0.8921 - val_accuracy: 0.4444
# Epoch 18/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.7395 - accuracy: 0.5714 - val_loss: 0.8740 - val_accuracy: 0.4444
# Epoch 19/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.7201 - accuracy: 0.5714 - val_loss: 0.8548 - val_accuracy: 0.4444
# Epoch 20/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6983 - accuracy: 0.5714 - val_loss: 0.8346 - val_accuracy: 0.4444
# Epoch 21/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.6757 - accuracy: 0.6190 - val_loss: 0.8135 - val_accuracy: 0.5556
# Epoch 22/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.6535 - accuracy: 0.6667 - val_loss: 0.7910 - val_accuracy: 0.5556
# Epoch 23/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.6321 - accuracy: 0.7143 - val_loss: 0.7665 - val_accuracy: 0.6667
# Epoch 24/200
# 1/1 [==============================] - 0s 31ms/step - loss: 0.
- val_loss: 0.0330 - val_accuracy: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 42ms/step - loss: 6.0160e-04 - accuracy: 1.0000 - val_loss: 0.0334 - val_accuracy: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 49ms/step - loss: 5.9604e-04 - accuracy: 1.0000 - val_loss: 0.0335 - val_accuracy: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 41ms/step - loss: 5.9044e-04 - accuracy: 1.0000 - val_loss: 0.0333 - val_accuracy: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 40ms/step - loss: 5.8484e-04 - accuracy: 1.0000 - val_loss: 0.0328 - val_accuracy: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 35ms/step - loss: 5.7929e-04 - accuracy: 1.0000 - val_loss: 0.0323 - val_accuracy: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 40ms/step - loss: 5.7397e-04 - accuracy: 1.0000 - val_loss: 0.0319 - val_accuracy: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 48ms/step - loss: 5.6883e-04 - accuracy: 1.0000 - val_loss: 0.0317 - val_accuracy: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 57ms/step - loss: 5.6378e-04 - accuracy: 1.0000 - val_loss: 0.0318 - val_accuracy: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 40ms/step - loss: 5.5871e-04 - accuracy: 1.0000 - val_loss: 0.0321 - val_accuracy: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 49ms/step - loss: 5.5369e-04 - accuracy: 1.0000 - val_loss: 0.0326 - val_accuracy: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 63ms/step - loss: 5.4877e-04 - accuracy: 1.0000 - val_loss: 0.0331 - val_accuracy: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 49ms/step - loss: 5.4400e-04 - accuracy: 1.0000 - val_loss: 0.0334 - val_accuracy: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 64ms/step - loss: 5.3930e-04 - accuracy: 1.0000 - val_loss: 0.0336 - val_accuracy: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 46ms/step - loss: 5.3471e-04 - accuracy: 1.0000 - val_loss: 0.0336 - val_accuracy: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 49ms/step - loss: 5.3013e-04 - accuracy: 1.0000 - val_loss: 0.0334 - val_accuracy: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 50ms/step - loss: 5.2561e-04 - accuracy: 1.0000 - val_loss: 0.0332 - val_accuracy: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 39ms/step - loss: 5.2116e-04 - accuracy: 1.0000 - val_loss: 0.0329 - val_accuracy: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 37ms/step - loss: 5.1683e-04 - accuracy: 1.0000 - val_loss: 0.0328 - val_accuracy: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 54ms/step - loss: 5.1256e-04 - accuracy: 1.0000 - val_loss: 0.0328 - val_accuracy: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 63ms/step - loss: 5.0836e-04 - accuracy: 1.0000 - val_loss: 0.0329 - val_accuracy: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 53ms/step - loss: 5.0422e-04 - accuracy: 1.0000 - val_loss: 0.0331 - val_accuracy: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 71ms/step - loss: 5.0008e-04 - accuracy: 1.0000 - val_loss: 0.0334 - val_accuracy: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 38ms/step - loss: 4.9603e-04 - accuracy: 1.0000 - val_loss: 0.0337 - val_accuracy: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 32ms/step - loss: 4.9207e-04 - accuracy: 1.0000 - val_loss: 0.0339 - val_accuracy: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 32ms/step - loss: 4.8815e-04 - accuracy: 1.0000 - val_loss: 0.0341 - val_accuracy: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 48ms/step - loss: 4.8430e-04 - accuracy: 1.0000 - val_loss: 0.0341 - val_accuracy: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 56ms/step - loss: 4.8049e-04 - accuracy: 1.0000 - val_loss: 0.0340 - val_accuracy: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 75ms/step - loss: 4.7673e-04 - accuracy: 1.0000 - val_loss: 0.0339 - val_accuracy: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 51ms/step - loss: 4.7302e-04 - accuracy: 1.0000 - val_loss: 0.0338 - val_accuracy: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 40ms/step - loss: 4.6939e-04 - accuracy: 1.0000 - val_loss: 0.0338 - val_accuracy: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 40ms/step - loss: 4.6580e-04 - accuracy: 1.0000 - val_loss: 0.0338 - val_accuracy: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 53ms/step - loss: 4.6224e-04 - accuracy: 1.0000 - val_loss: 0.0339 - val_accuracy: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 56ms/step - loss: 4.5875e-04 - accuracy: 1.0000 - val_loss: 0.0341 - val_accuracy: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 60ms/step - loss: 4.5530e-04 - accuracy: 1.0000 - val_loss: 0.0343 - val_accuracy: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 56ms/step - loss: 4.5186e-04 - accuracy: 1.0000 - val_loss: 0.0345 - val_accuracy: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 39ms/step - loss: 4.4849e-04 - accuracy: 1.0000 - val_loss: 0.0347 - val_accuracy: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 40ms/step - loss: 4.4519e-04 - accuracy: 1.0000 - val_loss: 0.0348 - val_accuracy: 1.0000
# Model Training Completed
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0108 - accuracy: 1.0000
# Model Evaluation Completed
# Loss: 0.010752744041383266  Accuracy: 1.0

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.model_selection import cross_val_score, cross_val_predict

# Assuming you have already trained your models and obtained predictions
# y_test are the true labels and y_pred_lr are the predicted labels

# Compute evaluation metrics
accuracy = accuracy_score(y_test, y_pred_dt)
precision = precision_score(y_test, y_pred_dt, average='weighted')
recall = recall_score(y_test, y_pred_dt, average='weighted')
f1 = f1_score(y_test, y_pred_dt, average='weighted')
cm = confusion_matrix(y_test, y_pred_dt)
print(cm)
# Out:
# [[4 4 5]
#  [2 4 2]
#  [6 2 1]]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.model_selection import cross_val_score, cross_val_predict

# Assuming you have already trained your models and obtained predictions
# y_test are the true labels and y_pred_lr are the predicted labels

# Compute evaluation metrics
accuracy = accuracy_score(y_test, y_pred_lr)
precision = precision_score(y_test, y_pred_lr, average='weighted')
recall = recall_score(y_test, y_pred_lr, average='weighted')
f1 = f1_score(y_test, y_pred_lr, average='weighted')
cm = confusion_matrix(y_test, y_pred_lr)
print(cm)

# Display confusion matrix
# Out:
# [[3 3 7]
#  [1 4 3]
#  [5 1 3]]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.model_selection import cross_val_score, cross_val_predict

# Assuming you have already trained your models and obtained predictions
# y_test are the true labels and y_pred_lr are the predicted labels

# Compute evaluation metrics
accuracy = accuracy_score(y_test, y_pred_rf)
precision = precision_score(y_test, y_pred_rf, average='weighted')
recall = recall_score(y_test, y_pred_rf, average='weighted')
f1 = f1_score(y_test, y_pred_rf, average='weighted')
cm = confusion_matrix(y_test, y_pred_rf)
print(cm)

# Display confusion matrix
# Out:
# [[3 3 7]
#  [1 4 3]
#  [5 0 4]]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.model_selection import cross_val_score, cross_val_predict

# Assuming you have already trained your models and obtained predictions
# y_test are the true labels and y_pred_lr are the predicted labels

# Compute evaluation metrics
accuracy = accuracy_score(y_test, y_pred_svm)
precision = precision_score(y_test, y_pred_svm, average='weighted')
recall = recall_score(y_test, y_pred_svm, average='weighted')
f1 = f1_score(y_test, y_pred_svm, average='weighted')
cm = confusion_matrix(y_test, y_pred_svm)
print(cm)

# Display confusion matrix
# Out:
# [[3 3 7]
#  [1 4 3]
#  [5 1 3]]

# %%
import seaborn as sns

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test, y_pred_lr, labels=lr.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=lr.classes_)
disp.plot()

# %%
cm = confusion_matrix(y_test, y_pred_dt, labels=dt.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=dt.classes_)
disp.plot()

# %%
from sklearn import tree
feature_names = ['Total_Items', 'Time_Spent_ in Course', 'Total_Logins',
       'Activity_inside_content_ area', 'User_Activity_in_Goup',
       'Nbre_of_clics', 'Nbre_of_ message_ participation', 'join_session',
       'Time_Spent_on_Session_Attendence', 'Level']
class_names = ['AE','PE','NE']
fig,axes = plt.subplots(nrows = 1, ncols=1,figsize = (4,4), dpi = 300)
tree.plot_tree(dt,feature_names = feature_names,class_names= class_names,filled= True);

# %%
df.dtypes
df
# Out:
#     Total_Items  Time_Spent_ in Course  Total_Logins  \
# 0      0.506494               1.000000      0.316754
# 1      0.194805               0.005378      0.164921
# 2      0.402597               0.109859      0.253927
# 3      0.480519               0.438156      0.285340
# 4      0.168831               0.001024      0.083770
# ..          ...                    ...           ...
# 95     0.831169               0.385915      0.204188
# 96     0.831169               0.385915      0.204188
# 97     0.116883               0.032522      0.057592
# 98     0.792208               0.258899      1.000000
# 99     0.051948               0.187196      0.000000
#
#     Activity_inside_content_ area  User_Activity_in_Goup  Nbre_of_clics  \
# 0                        0.370166               0.097561       0.592593
# 1                        0.104972               0.024390       0.296296
# 2                        0.241252               0.008130       0.296296
# 3                        0.237569               0.097561       0.407407
# 4                        0.081031               0.406504       0.000000
# ..                            ...                    ...            ...
# 95                       0.267035               0.162602       0.481481
# 96                       0.267035               0.162602       0.481481
# 97                       0.046041               0.032520       0.259259
# 98                       1.000000               0.975610       0.777778
# 99                       0.007366               0.048780       0.000000
#
#     Nbre_of_ message_ participation  join_session  \
# 0                          0.444444      0.555556
# 1                          0.111111      0.000000
# 2                          0.333333      0.777778
# 3                          0.333333      0.888889
# 4                          0.000000      0.333333
# ..                              ...           ...
# 95                         0.777778      1.000000
# 96                         0.777778      1.000000
# 97                         0.000000      0.444444
# 98                         0.888889      1.000000
# 99                         0.000000      0.111111
#
#     Time_Spent_on_Session_Attendence
# 0                           0.466667
# 1                           0.066667
# 2                           0.600000
# 3                           0.666667
# 4                           0.400000
# ..                               ...
# 95                          0.466667
# 96                          0.466667
# 97                          0.200000
# 98                          0.000000
# 99                          0.000000
#
# [100 rows x 9 columns]

# %%
cm = confusion_matrix(y_test, y_pred_rf, labels=rf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=rf.classes_)
disp.plot()

# %%
cm = confusion_matrix(y_test, y_pred_svm, labels=svm.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=svm.classes_)
disp.plot()

# %%
print(type(y))
# Out:
# <class 'numpy.ndarray'>

# %%
import joblib
joblib.dump(dt, 'dt_model.pkl')
joblib.dump(svm, 'svm_model.pkl')
joblib.dump(lr, 'lr_model.pkl')
joblib.dump(rf, 'rf1_model.pkl')
# Out:
# ['rf1_model.pkl']
